# %% [markdown]
# ![NETFLIX LOGO](NETFLIX_LOGO.jpg)

# %% [markdown]
# <img src="C\\Users\\Hp\\Desktop\\NETFLIX DAP\\NETFLIX_IMAGE.jpg">

# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %% [markdown]
# ### IMPORT THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### LOAD THE DATA

# %%
data=pd.read_csv('C:\\Users\\Hp\\Desktop\\NETFLIX DAP\\netflix_dataset.csv')
data
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# ...

# %%
data.shape #used to find the dimensions of dataset(numberofrows, numberofcolumns)
# Out:
# (5837, 12)

# %%
data.head() #it can print first 5 rows by default
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# ...

# %%
data.tail(10) #it an print last 10 rows
# Out:
#        show_id                        title                       director  \
# 5827  70206824         Triumph of the Heart               Richard Michaels
# 5828  70206825             Unspeakable Acts                     Linda Otto
# 5829  70206826             Victim of Beauty                    Roger Young
# 5830  60003155       Joseph: King of Dreams  Rob LaDuca, Robert C. Ramirez
# 5831  70154110                Even the Rain                  Icíar Bollaín
# 5832  70141644  Mad Ron's Prevues from Hell                     Jim Monaco
# 5833  70127998                     Splatter                      Joe Dante
# 5834  70084180      Just Another Love Story                   Ole Bornedal
# 5835  70157452              Dinner for Five                            NaN
# 5836  70053412         To and From New York           Sorin Dan Mihalcescu
#
#                                                    cast  \
# 5827  Mario Van Peebles, Susan Ruttan, Lane R. Davis...
# ...

# %%
data.info() #datatypes and summary of the metadata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 547.3+ KB

# %%
data.isnull() #used to check is there any null values in data
# Out:
#       show_id  title  director   cast  country  date_added  release_year  \
# 0       False  False      True  False    False       False         False
# 1       False  False     False  False     True       False         False
# 2       False  False     False  False    False       False         False
# 3       False  False     False  False    False       False         False
# 4       False  False      True  False    False        True         False
# ...       ...    ...       ...    ...      ...         ...           ...
# 5832    False  False     False  False    False       False         False
# 5833    False  False     False  False    False       False         False
# 5834    False  False     False  False    False       False         False
# 5835    False  False      True   True    False       False         False
# 5836    False  False     False  False    False       False         False
#
#       rating  duration  listed_in  description   type
# ...

# %%
data.describe() #it provides a statistical summary of only numerical columns in the dataset.
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
#i want to rename the column name diretor into Directors_Name
data.rename(columns={'director':'Directors'},inplace=True) #Rename the columns in the original DataFrame without creating new dataframe

# %%
data.columns #it display the column names in the dataframe. and column renamed director to Directors
# Out:
# Index(['show_id', 'title', 'Directors', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'type'],
#       dtype='object')

# %%
data.nunique()  #Counts unique values in each column
# Out:
# show_id         5837
# title           5780
# Directors       3108
# cast            5087
# country          527
# date_added      1092
# release_year      71
# rating            14
# duration         194
# listed_in        449
# description     5829
# type               2
# dtype: int64

# %%
data.isnull().sum() #it shows total number of null values in each column
# Out:
# show_id            0
# title              0
# Directors       1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %%
#i want to add the missing value (null value) in the column of director
data['Directors'].fillna('not spicified', inplace=True) 
data['cast'].fillna('not spicified', inplace=True) 
data['country'].fillna('not spicified', inplace=True) 

#Replaced all null values in the column director with the string 'not specified

# %%
data.dropna(subset=['date_added'],inplace=True) #This will remove rows where the date_added column has NaN values.
data.dropna(subset=['rating'],inplace=True)

# %%
data.isnull().sum() #after replaced the null values in the all columns is zero
# Out:
# show_id         0
# title           0
# Directors       0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# type            0
# dtype: int64

# %%
data.duplicated() #Helps to detect duplicate rows in the dataset.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 5832    False
# 5833    False
# 5834    False
# 5835    False
# 5836    False
# Length: 5186, dtype: bool

# %%
data.duplicated().sum() #checking total number of dupliate values
# Out:
# 0

# %%
data['type'].unique() #it will return an array of unique values in the 'type' colums
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
data['title'].unique() #return an array of unique values in the "title" column.
# Out:
# array(['Chocolate', 'Guatemala: Heart of the Mayan World',
#        'The Zoya Factor', ..., 'Just Another Love Story',
#        'Dinner for Five', 'To and From New York'], dtype=object)

# %%
data['Directors'].unique() #It checks the Directors column and returns a list of unique values in that column, meaning no duplicates.
# Out:
# array(['not spicified', 'Luis Ara, Ignacio Jaunsolo', 'Abhishek Sharma',
#        ..., 'Jim Monaco', 'Ole Bornedal', 'Sorin Dan Mihalcescu'],
#       dtype=object)

# %%
data['cast'].unique() #return an array of unique values in the "cast" column.
# Out:
# array(['Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Lee Jae-ryong, Min Jin-woong, Kim Won-hae, Yoo Teo',
#        'Christian Morales',
#        'Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, Sikander Kher, Angad Bedi, Koel Purie, Pooja Bhamrah, Manu Rishi Chadha',
#        ...,
#        'Corey Feldman, Tony Todd, Tara Leigh, Erin Way, Mark Alan, Stuart Pankin',
#        'Anders W. Berthelsen, Rebecka Hemse, Nikolaj Lie Kaas, Charlotte Fich, Dejan Cukic, Karsten Jansfort, Flemming Enevold, Bent Mejding, Ewa Fröling, Josephine Raahauge, Timm Vladimir, Ditte Hansen',
#        'Barbara King, Shaana Diya, John Krisiukenas, Yoriko Haraguchi, David Crane, Chad Thomas'],
#       dtype=object)

# %%
data['date_added'].unique() #return an array of unique values in the "date_added" column.
# Out:
# array(['November 30, 2019', 'November 29, 2019', 'November 28, 2019', ...,
#        'May 5, 2009', 'February 4, 2008', 'January 1, 2008'], dtype=object)

# %%
data['rating'].unique()
# Out:
# array(['TV-14', 'TV-G', 'TV-MA', 'TV-PG', 'R', 'TV-Y7', 'TV-Y', 'PG', 'G',
#        'PG-13', 'TV-Y7-FV', 'NR', 'UR', 'NC-17'], dtype=object)

# %%
data['release_year'].unique()
# Out:
# array([2019, 2018, 2016, 2017, 2001, 2008, 1980, 1973, 2012, 1987, 2002,
#        2015, 2013, 1996, 1992, 2007, 2009, 1995, 2014, 1968, 2010, 1999,
#        2011, 2000, 1974, 1997, 1993, 2006, 2005, 2003, 2004, 2020, 1998,
#        1960, 1958, 1965, 1956, 1978, 1990, 1976, 1962, 1955, 1972, 1991,
#        1988, 1989, 1975, 1985, 1984, 1970, 1994, 1982, 1983, 1967, 1981,
#        1979, 1986, 1925, 1946, 1977, 1959, 1966, 1971, 1969, 1945, 1942,
#        1944, 1947, 1943, 1954], dtype=int64)

# %%
data['duration'].unique()
# Out:
# array(['1 Season', '67 min', '135 min', '106 min', '107 min', '81 min',
#        '118 min', '110 min', '104 min', '93 min', '94 min', '124 min',
#        '137 min', '134 min', '69 min', '209 min', '86 min', '24 min',
#        '46 min', '117 min', '87 min', '92 min', '114 min', '121 min',
#        '109 min', '96 min', '97 min', '56 min', '119 min', '138 min',
#        '111 min', '88 min', '73 min', '116 min', '85 min', '102 min',
#        '101 min', '28 min', '103 min', '131 min', '166 min', '105 min',
#        '82 min', '84 min', '112 min', '89 min', '136 min', '129 min',
#        '158 min', '78 min', '100 min', '74 min', '60 min', '143 min',
#        '98 min', '54 min', '59 min', '95 min', '61 min', '123 min',
#        '44 min', '68 min', '99 min', '91 min', '40 min', '90 min',
#        '108 min', '200 min', '133 min', '115 min', '55 min', '153 min',
#        '185 min', '127 min', '120 min', '139 min', '122 min', '36 min',
# ...

# %%
data['country'].unique()
# Out:
# array(['South Korea', 'not spicified', 'India',
#        'France, Senegal, Belgium', 'Nigeria', 'France', 'South Africa',
#        'United States', 'Japan', 'Brazil',
#        'Germany, Canada, United States', 'Canada, Norway', 'Mexico',
#        'China', 'United States, United Arab Emirates',
#        'United States, Japan', 'Singapore, United States',
#        'United Kingdom, Germany, Canada, United States',
#        'Australia, France', 'Germany', 'Germany, United Kingdom',
#        'Italy, United States',
#        'United States, New Zealand, United Kingdom',
#        'United Kingdom, Germany, United States', 'United States, Germany',
#        'Argentina', 'Taiwan', 'Finland, Germany, Belgium',
#        'United Kingdom, France', 'United States, Spain, Chile, Peru',
#        'Colombia', 'Spain', 'United States, Ireland',
#        'India, United States', 'Thailand',
#        'Argentina, United States, Mexico', 'United Kingdom',
# ...

# %%
data['listed_in'].unique()
# Out:
# array(['International TV Shows, Korean TV Shows, Romantic TV Shows',
#        'Documentaries, International Movies',
#        'Comedies, Dramas, International Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Comedies, International Movies, Thrillers',
#        'Dramas, International Movies', 'Comedies, International Movies',
#        'Comedies, Independent Movies, International Movies', 'Reality TV',
#        'Action & Adventure, Comedies, International Movies',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'Dramas, International Movies, Thrillers', 'Docuseries',
#        'Children & Family Movies, Dramas',
#        'Anime Series, International TV Shows',
#        'International TV Shows, Stand-Up Comedy & Talk Shows, TV Comedies',
#        'TV Comedies', 'International TV Shows, TV Comedies, TV Dramas',
#        'Dramas, Thrillers', 'Action & Adventure, Dramas',
#        'Comedies, International Movies, Romantic Movies',
# ...

# %%
data['description'].unique()
# Out:
# array(['Brought together by meaningful meals in the past and present, a doctor and a chef are reacquainted when they begin working at a hospice ward.',
#        "From Sierra de las Minas to Esquipulas, explore Guatemala's cultural and geological wealth, including ancient Mayan cities and other natural wonders.",
#        'A goofy copywriter unwittingly convinces the Indian cricket team that she’s their lucky mascot, to the dismay of their superstition-shunning captain.',
#        ...,
#        'When he causes a car accident that leaves a young woman with amnesia, a man finds himself telling incredible lies to make her and her family happy.',
#        'In each episode, four celebrities join host Jon Favreau for dinner and share revealing stories about both show business and their personal lives.',
#        'While covering a story in New York City, a Seattle-based reporter uncovers a link between two missing women that changes her article entirely.'],
#       dtype=object)

# %% [markdown]
#  # 4 DATA ANALYSIS AND DATA VISUALIZATION

# %% [markdown]
# ## i) Plot the count of different types of shows availble on netflix

# %%
type_counts = data['type'].value_counts()

# %%
# Define colors (matching Netflix pattern)
colors = ['blue', 'red']

# Create bar chart
plt.bar(type_counts.index, type_counts.values, color=colors)

# Add title and labels
plt.title('Count of Different Shows in NETFLIX')
plt.xlabel('Type')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# observations from the graph:
# 1. Netflix contains more movies than TV shows.
# 2. It indicates that Movies has more audience than  TV Shows.

# %%
data['type'].value_counts()

# %% [markdown]
# ## ii) Plot the Distribution of Release years

# %%
plt.hist(data['release_year'], bins=100, color='b', edgecolor='black')

# Add title and labels
plt.title("Distribution of Release Years")
plt.xlabel("Release Year")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# observations from the above graph:
# 1. Most number of releases are during the period 2000-2020
# 2. Highest no: of releases are in the year 2018

# %%
data['release_year'].value_counts()
# Out:
# 2018    890
# 2017    826
# 2016    746
# 2019    590
# 2015    458
#        ...
# 1969      1
# 1956      1
# 2020      1
# 1947      1
# 1954      1
# Name: release_year, Length: 70, dtype: int64

# %% [markdown]
# ## iii) Top 10 countries with highest content

# %%
data['country'].value_counts().head(10)
# Out:
# United States     1641
# India              693
# not spicified      393
# United Kingdom     270
# Japan              122
# South Korea        119
# Canada             105
# Spain               99
# France              78
# Mexico              76
# Name: country, dtype: int64

# %%
data.country.value_counts().head(10)
# Out:
# United States     1641
# India              693
# not spicified      393
# United Kingdom     270
# Japan              122
# South Korea        119
# Canada             105
# Spain               99
# France              78
# Mexico              76
# Name: country, dtype: int64

# %%
top_countries=data['country'].value_counts().head(10)

# %%
colors = ['blue', 'red', 'green', 'purple', 'orange', 'cyan', 'magenta', 'yellow', 'pink', 'brown']

plt.bar(top_countries.index, top_countries.values, color=colors)

# Rotate x-axis labels for better readability
plt.xticks(rotation=60)

# Add labels and title
plt.ylabel("Count of Contents")
plt.xlabel("Country")
plt.title("Top 10 Countries with Highest No. of Contents")

# Show the plot
plt.show()

# %% [markdown]
# observations from the graph:
# 1. Netflix has a greater number of contents from United States.
# 2. India stands out in the second position.

# %% [markdown]
# ## iV) list out TV shows from India?

# %%
data[(data['type']=='TV Show')&(data['country']=='India')]['title']
# Out:
# 361                 Mighty Little Bheem: Diwali
# 456                             College Romance
# 460                           Engineering Girls
# 464                                Girls Hostel
# 471                                     Inmates
# 521                               Bard of Blood
# 826                            Regiment Diaries
# 847                                   7 (Seven)
# 898                                  Typewriter
# 943                                Chhota Bheem
# 1125                                      Leila
# 1248                                  Thackeray
# 1565    Midnight Misadventures With Mallika Dua
# 1577                                The Calling
# 1621                                Delhi Crime
# 1753              Cricket Fever: Mumbai Indians
# 2166                              Selection Day
# 2230                        Anjaan: Rural Myths
# 2301               21 Sarfarosh: Saragarhi 1897
# 2562              Devlok with Devdutt Pattanaik
# ...

# %% [markdown]
# ## V) list out Movies from India?

# %%
data[(data['type']=='Movie')&(data['country']=='India')]['title']
# Out:
# 2           The Zoya Factor
# 24      Evvarikee Cheppoddu
# 34                  Pranaam
# 69                Dorasaani
# 78                Mallesham
#                ...
# 5407                  Harud
# 5420                 Umrika
# 5478                 Dhanak
# 5485            John & Jane
# 5545     X: Past Is Present
# Name: title, Length: 645, dtype: object

# %% [markdown]
# ## Vi) Top 10 Directors with the highest no: of contents

# %%
data['Directors'].value_counts().head(10)
# Out:
# not spicified             1291
# Raúl Campos, Jan Suter      18
# Marcus Raboy                14
# Jay Karas                   13
# Jay Chapman                 12
# Martin Scorsese              8
# Steven Spielberg             8
# Johnnie To                   8
# Shannon Hartman              7
# Hakan Algül                  7
# Name: Directors, dtype: int64

# %% [markdown]
# ## Vii) List all the movies of Mohanlal (actor)?

# %%
data[data['cast'].str.contains('Mohanlal')]
# Out:
#        show_id        title        Directors  \
# 2469  70241088  Grandmaster  B. Unnikrishnan
# 3615  60036613      Company  Ram Gopal Varma
# 4043  70236586         Tezz     Priyadarshan
#
#                                                    cast  \
# 2469  Mithra Kurian, Anoop Menon, Mohanlal, Narein, ...
# 3615  Ajay Devgn, Vivek Oberoi, Mohanlal, Manisha Ko...
# 4043  Anil Kapoor, Ajay Devgn, Boman Irani, Kangna R...
#
#                     country        date_added  release_year rating duration  \
# 2469                  India  November 1, 2018          2012  TV-14  133 min
# 3615                  India     March 1, 2018          2002  TV-MA  137 min
# 4043  United Kingdom, India  December 1, 2017          2012  TV-MA  121 min
#
#                                               listed_in  \
# 2469                    International Movies, Thrillers
# 3615   Action & Adventure, Dramas, International Movies
# 4043  Action & Adventure, International Movies, Musi...
#
# ...

# %% [markdown]
# ## Viii) How many Movies got the 'TV-14' rating in India?

# %%
data[(data['rating']=='TV-14') & (data['country']=='India')]
# Out:
#        show_id                title                    Directors  \
# 2     81213894      The Zoya Factor              Abhishek Sharma
# 24    81194544  Evvarikee Cheppoddu         Basava Shankar Eeday
# 69    81217738            Dorasaani                 KVR Mahendra
# 111   81076114         House Arrest  Shashanka Ghosh, Samit Basu
# 151   80127886               U Turn                  Pawan Kumar
# ...        ...                  ...                          ...
# 5258  80139507  Famous in Ahmedabad                 Hardik Mehta
# 5340  70260514      Mumbai Cha Raja                Manjeet Singh
# 5407  70153553                Harud                 Aamir Bashir
# 5420  80038288               Umrika                Prashant Nair
# 5485  80115844          John & Jane              Ashim Ahluwalia
#
#                                                    cast country  \
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...   India
# ...

# %% [markdown]
# ## ix) Which individual country has the highest no: of TV Shows?

# %%
data[data['type']=='TV Show']['country'].value_counts().head(1)
# Out:
# United States    269
# Name: country, dtype: int64

# %% [markdown]
# ## x) Top 10 Genres with the Most Content on Netflix

# %%
#Extracting unique genres from the 'listed_in' column
all_genres = ', '.join(data['listed_in']).split(', ')

#Get the unique genres by converting the list into a set (removes duplicates) and back into a list
unique_genres = list(set(all_genres))

#Count how many times each genre appears in the list
genre_counts = {}  # Start with an empty dictionary
for genre in unique_genres: #it will iterate the genres one by one(Action,Comedy,Action,Drama,Action,Comedy)
    genre_counts[genre] = all_genres.count(genre)  # it will Count each genre's occurrences in all_gnres list

#Get the top 10 genres with the most content
top_genres = dict(sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)[:10])

#genre_counts.items() => This takes the genre_counts dictionary and converts it into a list of key-value pairs (tuples). example:[('Action', 3), ('Comedy', 2), ('Drama', 1)]
#reverse=True => it would sort in ascending order (lowest count to highest count).

# %%
#Create a horizontal bar plot using Matplotlib
plt.barh(list(top_genres.keys()), list(top_genres.values()), color='purple')

#Add labels and title
plt.xlabel('Number of Contents')
plt.ylabel('Genre')
plt.title('Top 10 Genres with the Most Content on Netflix')

# Show the plot
plt.show()
